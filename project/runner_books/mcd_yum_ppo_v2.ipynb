# %%
import sys
sys.path.append("../")

import numpy as np
from statsmodels.tsa.vector_ar.vecm import coint_johansen
from statsmodels.tsa.ar_model import AutoReg
from data_loader import PairData

data = PairData("../../data/real_pair_MCD_YUM.csv")
n  = len(data)
q1 = n // 4
q4 = 3 * n // 4   # test starts here (real Q4)

# Estimate from Q1
jres      = coint_johansen(np.log(data.s[:, :q1]).T, det_order=0, k_ar_diff=1)
cv        = jres.evec[:, 0]
beta      = -cv[1] / cv[0]
intercept = float((np.log(data.s[0, :q1]) - beta * np.log(data.s[1, :q1])).mean())
spread_q1 = np.log(data.s[0, :q1]) - beta * np.log(data.s[1, :q1]) - intercept
fixed_std = float(spread_q1.std())
phi       = AutoReg(spread_q1, lags=1).fit().params[1]
wn_var    = fixed_std ** 2 * (1 - phi ** 2)

print(f"β={beta:.4f}  intercept={intercept:.4f}  std={fixed_std:.4f}  φ={phi:.4f}")
print(f"Real test (Q4): {q4}–{n}  ({n - q4} steps)")

# Generate 50 synthetic series of length q4 (= Q1+Q2+Q3)
N, T = 10, q4
log_s1 = np.cumsum(np.c_[np.full(N, np.log(100.0)),
                          0.0005 + 0.015 * np.random.randn(N, T - 1)], axis=1)
noise      = np.sqrt(wn_var) * np.random.randn(N, T)
spread_all = np.zeros((N, T))
for t in range(1, T):
    spread_all[:, t] = phi * spread_all[:, t - 1] + noise[:, t]

log_s0 = beta * log_s1 + intercept + spread_all
pairs  = np.stack([np.exp(log_s0), np.exp(log_s1)], axis=1)  # (N, 2, T)

print(f"Generated {N} synthetic series of length {T}  |  spread std: {spread_all.std(axis=1).mean():.4f} (target {fixed_std:.4f})")
# Out:
# β=1.0437  intercept=0.5396  std=0.1157  φ=0.9893
# Real test (Q4): 3774–5032  (1258 steps)
# Generated 10 synthetic series of length 3774  |  spread std: 0.1154 (target 0.1157)

# %%
# %matplotlib widget

import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from env import Market

class SyntheticMarket(gym.Wrapper):
    """On each reset, samples a new random synthetic series."""
    def __init__(self, pairs, **market_kwargs):
        self._pairs = pairs
        env = Market(self._make_pair(0), **market_kwargs)
        super().__init__(env)

    def _make_pair(self, idx):
        pd = object.__new__(PairData)
        pd.s = self._pairs[idx]
        pd.labels = ["s0", "s1"]
        pd.timestamps = np.arange(self._pairs.shape[2])
        return pd

    def reset(self, **kwargs):
        idx = np.random.randint(len(self._pairs))
        self.env._pair_data = self._make_pair(idx)
        return self.env.reset(**kwargs)

class FlatMarket(gym.Wrapper):
    """Obs: [position, |z|, |entry_z|, |spread|, |entry_spread|].
    Pure magnitudes — no sign — agent physically cannot be biased toward one side."""
    def __init__(self, env):
        super().__init__(env)
        self.observation_space = spaces.Box(
            low= np.zeros(5, dtype=np.float32),
            high=np.array([1.0, np.inf, np.inf, np.inf, np.inf], dtype=np.float32),
        )

    def _flatten(self, obs):
        return np.array([
            float(obs["position"]),
            abs(float(obs["spread_z_score"][0])),
            abs(float(obs["entry_z_score"][0])),
            abs(float(obs["spread"][0])),
            abs(float(obs["entry_spread"][0])),
        ], dtype=np.float32)

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        return self._flatten(obs), info

    def step(self, action):
        obs, reward, term, trunc, info = self.env.step(action)
        return self._flatten(obs), reward, term, trunc, info

train_env = FlatMarket(SyntheticMarket(
    pairs,
    fixed_beta=beta,
    spread_intercept=intercept,
    fixed_std=fixed_std,
    reward_alpha=0.05,
    transaction_cost=0.002,
    squared_reward=True,
))

TOTAL_STEPS = N * T * 5
print(f"Training for {TOTAL_STEPS:,} steps across {N} synthetic series...")

model = PPO("MlpPolicy", train_env, verbose=1,
            n_steps=2048, batch_size=64, n_epochs=10,
            ent_coef=0.1, gae_lambda=0.99)
model.learn(total_timesteps=TOTAL_STEPS)
print("Done.")
# Out:
# Training for 188,700 steps across 10 synthetic series...
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 3473 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.71e+03    |
# |    ep_rew_mean          | -7.78e+05   |
# | time/                   |             |
# |    fps                  | 1585        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 7.67468e-08 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.693      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.59e+11    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -9.7e-06    |
# |    value_loss           | 6e+11       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | -7.78e+05     |
# | time/                   |               |
# |    fps                  | 1643          |
# |    iterations           | 3             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 1.8218998e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -8.34e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.53e+11      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -2.28e-06     |
# |    value_loss           | 2.29e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 4.68e+06      |
# | time/                   |               |
# |    fps                  | 1701          |
# |    iterations           | 4             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.3766112e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -3.58e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.79e+11      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -1.12e-06     |
# |    value_loss           | 4.97e+11      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 4.68e+06      |
# | time/                   |               |
# |    fps                  | 1677          |
# |    iterations           | 5             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 4.4418266e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.43e+11      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -1.47e-05     |
# |    value_loss           | 6.94e+11      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 3.05e+06      |
# | time/                   |               |
# |    fps                  | 1576          |
# |    iterations           | 6             |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 1.4319085e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.23e+11      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -2.61e-08     |
# |    value_loss           | 5.27e+11      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 3.05e+06      |
# | time/                   |               |
# |    fps                  | 1583          |
# |    iterations           | 7             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 9.8953024e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.3e+11       |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -4.99e-06     |
# |    value_loss           | 1.28e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 3.85e+06      |
# | time/                   |               |
# |    fps                  | 1583          |
# |    iterations           | 8             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 1.4872057e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.58e+12      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -5.88e-07     |
# |    value_loss           | 2.7e+12       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 3.85e+06      |
# | time/                   |               |
# |    fps                  | 1601          |
# |    iterations           | 9             |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 1.7520506e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.38e+11      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -1.59e-06     |
# |    value_loss           | 1.27e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.44e+07      |
# | time/                   |               |
# |    fps                  | 1620          |
# |    iterations           | 10            |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 1.4202669e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.63e+12      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -6.32e-07     |
# |    value_loss           | 3.18e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.4e+07       |
# | time/                   |               |
# |    fps                  | 1607          |
# |    iterations           | 11            |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 1.3885438e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.64e+11      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | 1.15e-06      |
# |    value_loss           | 9.6e+11       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.4e+07       |
# | time/                   |               |
# |    fps                  | 1623          |
# |    iterations           | 12            |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 1.4959369e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.59e+11      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -1.5e-06      |
# |    value_loss           | 1.79e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.62e+07      |
# | time/                   |               |
# |    fps                  | 1629          |
# |    iterations           | 13            |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 1.2165401e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.38e+11      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -6.57e-07     |
# |    value_loss           | 8.99e+11      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.62e+07      |
# | time/                   |               |
# |    fps                  | 1580          |
# |    iterations           | 14            |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 7.7241566e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.55e+11      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -1.84e-06     |
# |    value_loss           | 6.09e+11      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.71e+03     |
# |    ep_rew_mean          | 1.54e+07     |
# | time/                   |              |
# |    fps                  | 1600         |
# |    iterations           | 15           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 9.147334e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.47e+12     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -1.87e-06    |
# |    value_loss           | 2.34e+12     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.54e+07      |
# | time/                   |               |
# |    fps                  | 1567          |
# |    iterations           | 16            |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 1.5716068e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.15e+12      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -9.12e-07     |
# |    value_loss           | 4.18e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.51e+07      |
# | time/                   |               |
# |    fps                  | 1535          |
# |    iterations           | 17            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 2.3259781e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -1.55e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.03e+11      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -7.62e-06     |
# |    value_loss           | 1.31e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.51e+07      |
# | time/                   |               |
# |    fps                  | 1502          |
# |    iterations           | 18            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 1.4202669e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.89e+11      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -2.98e-08     |
# |    value_loss           | 9.67e+11      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.59e+07      |
# | time/                   |               |
# |    fps                  | 1479          |
# |    iterations           | 19            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 1.3416866e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 3.58e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.36e+11      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -6.16e-07     |
# |    value_loss           | 5.46e+11      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.71e+03     |
# |    ep_rew_mean          | 1.52e+07     |
# | time/                   |              |
# |    fps                  | 1453         |
# |    iterations           | 20           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 6.186019e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.97e+11     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -2.53e-05    |
# |    value_loss           | 8.14e+11     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.52e+07      |
# | time/                   |               |
# |    fps                  | 1462          |
# |    iterations           | 21            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 1.3562385e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.11e+11      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -1.09e-06     |
# |    value_loss           | 1.82e+12      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.71e+03    |
# |    ep_rew_mean          | 1.7e+07     |
# | time/                   |             |
# |    fps                  | 1474        |
# |    iterations           | 22          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 1.36788e-08 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.693      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.08e+11    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -1.25e-07   |
# |    value_loss           | 8.37e+11    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.7e+07       |
# | time/                   |               |
# |    fps                  | 1444          |
# |    iterations           | 23            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 1.3416866e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.79e+11      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -1.21e-07     |
# |    value_loss           | 1.93e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.89e+07      |
# | time/                   |               |
# |    fps                  | 1425          |
# |    iterations           | 24            |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 1.4144462e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.14e+12      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -3.68e-07     |
# |    value_loss           | 2.22e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.89e+07      |
# | time/                   |               |
# |    fps                  | 1434          |
# |    iterations           | 25            |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 1.3213139e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.64e+12      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -6.26e-07     |
# |    value_loss           | 3.53e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.27e+07      |
# | time/                   |               |
# |    fps                  | 1446          |
# |    iterations           | 26            |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 1.3591489e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.62e+12      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -2.91e-07     |
# |    value_loss           | 3.72e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.27e+07      |
# | time/                   |               |
# |    fps                  | 1455          |
# |    iterations           | 27            |
# |    time_elapsed         | 37            |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 1.2427336e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.15e+12      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -1.06e-06     |
# |    value_loss           | 5.41e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.15e+07      |
# | time/                   |               |
# |    fps                  | 1450          |
# |    iterations           | 28            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 1.5250407e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.22e+12      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -1.9e-06      |
# |    value_loss           | 6.25e+12      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.71e+03     |
# |    ep_rew_mean          | 2.15e+07     |
# | time/                   |              |
# |    fps                  | 1446         |
# |    iterations           | 29           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 1.481385e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.58e+12     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -4.85e-07    |
# |    value_loss           | 2.55e+12     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.27e+07      |
# | time/                   |               |
# |    fps                  | 1458          |
# |    iterations           | 30            |
# |    time_elapsed         | 42            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 1.1728844e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.7e+12       |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -8.97e-09     |
# |    value_loss           | 3.2e+12       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.01e+07      |
# | time/                   |               |
# |    fps                  | 1467          |
# |    iterations           | 31            |
# |    time_elapsed         | 43            |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 1.5599653e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.32e+12      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -1.91e-06     |
# |    value_loss           | 2.8e+12       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.71e+03    |
# |    ep_rew_mean          | 2.01e+07    |
# | time/                   |             |
# |    fps                  | 1477        |
# |    iterations           | 32          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 1.51922e-08 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.693      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.32e+12    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -1.95e-06   |
# |    value_loss           | 9.47e+12    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.95e+07      |
# | time/                   |               |
# |    fps                  | 1486          |
# |    iterations           | 33            |
# |    time_elapsed         | 45            |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 1.2543751e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.1e+12       |
# |    n_updates            | 320           |
# |    policy_gradient_loss | 1.76e-08      |
# |    value_loss           | 2.05e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.95e+07      |
# | time/                   |               |
# |    fps                  | 1495          |
# |    iterations           | 34            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 1.3416866e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.63e+12      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -6.72e-07     |
# |    value_loss           | 6.45e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.79e+07      |
# | time/                   |               |
# |    fps                  | 1479          |
# |    iterations           | 35            |
# |    time_elapsed         | 48            |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 1.5104888e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.26e+11      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -5.55e-08     |
# |    value_loss           | 1.22e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.79e+07      |
# | time/                   |               |
# |    fps                  | 1468          |
# |    iterations           | 36            |
# |    time_elapsed         | 50            |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 1.3859244e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.78e+12      |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -4.09e-06     |
# |    value_loss           | 4.62e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.8e+07       |
# | time/                   |               |
# |    fps                  | 1456          |
# |    iterations           | 37            |
# |    time_elapsed         | 52            |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 1.4202669e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.19e+11      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -8.73e-07     |
# |    value_loss           | 5.19e+11      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.8e+07       |
# | time/                   |               |
# |    fps                  | 1443          |
# |    iterations           | 38            |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 1.9437284e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.97e+11      |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -1.61e-05     |
# |    value_loss           | 8.85e+11      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 3.71e+03       |
# |    ep_rew_mean          | 2.09e+07       |
# | time/                   |                |
# |    fps                  | 1439           |
# |    iterations           | 39             |
# |    time_elapsed         | 55             |
# |    total_timesteps      | 79872          |
# | train/                  |                |
# |    approx_kl            | 1.39989424e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.693         |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0003         |
# |    loss                 | 5.64e+12       |
# |    n_updates            | 380            |
# |    policy_gradient_loss | 1.45e-07       |
# |    value_loss           | 1.04e+13       |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.71e+03     |
# |    ep_rew_mean          | 2.04e+07     |
# | time/                   |              |
# |    fps                  | 1429         |
# |    iterations           | 40           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 7.735798e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.35e+12     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -3.6e-06     |
# |    value_loss           | 3.21e+12     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.04e+07      |
# | time/                   |               |
# |    fps                  | 1438          |
# |    iterations           | 41            |
# |    time_elapsed         | 58            |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 1.4231773e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.17e+12      |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -1.54e-06     |
# |    value_loss           | 2.4e+12       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.1e+07       |
# | time/                   |               |
# |    fps                  | 1446          |
# |    iterations           | 42            |
# |    time_elapsed         | 59            |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 1.4202669e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.3e+11       |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -6.77e-07     |
# |    value_loss           | 1e+12         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.1e+07       |
# | time/                   |               |
# |    fps                  | 1453          |
# |    iterations           | 43            |
# |    time_elapsed         | 60            |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 1.3105455e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.79e+11      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | 2.2e-06       |
# |    value_loss           | 1.95e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.14e+07      |
# | time/                   |               |
# |    fps                  | 1461          |
# |    iterations           | 44            |
# |    time_elapsed         | 61            |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 1.3620593e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.88e+11      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -5.22e-08     |
# |    value_loss           | 5.2e+11       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.14e+07      |
# | time/                   |               |
# |    fps                  | 1467          |
# |    iterations           | 45            |
# |    time_elapsed         | 62            |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 1.3969839e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.69e+11      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -1.23e-06     |
# |    value_loss           | 1.09e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.12e+07      |
# | time/                   |               |
# |    fps                  | 1474          |
# |    iterations           | 46            |
# |    time_elapsed         | 63            |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 1.5250407e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.62e+12      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -3.6e-07      |
# |    value_loss           | 5.61e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.12e+07      |
# | time/                   |               |
# |    fps                  | 1481          |
# |    iterations           | 47            |
# |    time_elapsed         | 64            |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 1.4173565e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.28e+12      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -8.93e-07     |
# |    value_loss           | 2.35e+12      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 3.71e+03       |
# |    ep_rew_mean          | 1.88e+07       |
# | time/                   |                |
# |    fps                  | 1475           |
# |    iterations           | 48             |
# |    time_elapsed         | 66             |
# |    total_timesteps      | 98304          |
# | train/                  |                |
# |    approx_kl            | 1.36496965e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.693         |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0003         |
# |    loss                 | 1.28e+12       |
# |    n_updates            | 470            |
# |    policy_gradient_loss | -3.8e-07       |
# |    value_loss           | 3.09e+12       |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.71e+03     |
# |    ep_rew_mean          | 1.86e+07     |
# | time/                   |              |
# |    fps                  | 1481         |
# |    iterations           | 49           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 6.215996e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.18e+11     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -7.73e-06    |
# |    value_loss           | 7.79e+11     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.86e+07      |
# | time/                   |               |
# |    fps                  | 1485          |
# |    iterations           | 50            |
# |    time_elapsed         | 68            |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 2.3486791e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.25e+11      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | 1.37e-06      |
# |    value_loss           | 2.47e+11      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.77e+07      |
# | time/                   |               |
# |    fps                  | 1474          |
# |    iterations           | 51            |
# |    time_elapsed         | 70            |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 1.4755642e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.51e+11      |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -5.24e-07     |
# |    value_loss           | 8.13e+11      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 1.77e+07      |
# | time/                   |               |
# |    fps                  | 1480          |
# |    iterations           | 52            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 1.7986167e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.82e+12      |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -4.5e-06      |
# |    value_loss           | 5.91e+12      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.71e+03     |
# |    ep_rew_mean          | 1.83e+07     |
# | time/                   |              |
# |    fps                  | 1485         |
# |    iterations           | 53           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 5.237205e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# ...
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.63e+11      |
# |    n_updates            | 750           |
# |    policy_gradient_loss | 4.39e-06      |
# |    value_loss           | 1.65e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.08e+07      |
# | time/                   |               |
# |    fps                  | 1426          |
# |    iterations           | 77            |
# |    time_elapsed         | 110           |
# |    total_timesteps      | 157696        |
# | train/                  |               |
# |    approx_kl            | 1.4363031e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.88e+12      |
# |    n_updates            | 760           |
# |    policy_gradient_loss | -8.68e-07     |
# |    value_loss           | 3.64e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.14e+07      |
# | time/                   |               |
# |    fps                  | 1420          |
# |    iterations           | 78            |
# |    time_elapsed         | 112           |
# |    total_timesteps      | 159744        |
# | train/                  |               |
# |    approx_kl            | 2.5993795e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.97e+11      |
# |    n_updates            | 770           |
# |    policy_gradient_loss | -5.96e-05     |
# |    value_loss           | 1.24e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.14e+07      |
# | time/                   |               |
# |    fps                  | 1415          |
# |    iterations           | 79            |
# |    time_elapsed         | 114           |
# |    total_timesteps      | 161792        |
# | train/                  |               |
# |    approx_kl            | 1.5279511e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.42e+12      |
# |    n_updates            | 780           |
# |    policy_gradient_loss | -1.72e-07     |
# |    value_loss           | 3.02e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.15e+07      |
# | time/                   |               |
# |    fps                  | 1410          |
# |    iterations           | 80            |
# |    time_elapsed         | 116           |
# |    total_timesteps      | 163840        |
# | train/                  |               |
# |    approx_kl            | 1.5890691e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.1e+11       |
# |    n_updates            | 790           |
# |    policy_gradient_loss | -6.46e-07     |
# |    value_loss           | 6.08e+11      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.15e+07      |
# | time/                   |               |
# |    fps                  | 1405          |
# |    iterations           | 81            |
# |    time_elapsed         | 118           |
# |    total_timesteps      | 165888        |
# | train/                  |               |
# |    approx_kl            | 1.3504177e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.92e+11      |
# |    n_updates            | 800           |
# |    policy_gradient_loss | 7.22e-08      |
# |    value_loss           | 1.18e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.24e+07      |
# | time/                   |               |
# |    fps                  | 1401          |
# |    iterations           | 82            |
# |    time_elapsed         | 119           |
# |    total_timesteps      | 167936        |
# | train/                  |               |
# |    approx_kl            | 1.5250407e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.97e+11      |
# |    n_updates            | 810           |
# |    policy_gradient_loss | -1.91e-06     |
# |    value_loss           | 1e+12         |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 3.71e+03       |
# |    ep_rew_mean          | 2.24e+07       |
# | time/                   |                |
# |    fps                  | 1397           |
# |    iterations           | 83             |
# |    time_elapsed         | 121            |
# |    total_timesteps      | 169984         |
# | train/                  |                |
# |    approx_kl            | 1.48429535e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.693         |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0003         |
# |    loss                 | 1.56e+12       |
# |    n_updates            | 820            |
# |    policy_gradient_loss | -7.43e-07      |
# |    value_loss           | 3.26e+12       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.33e+07      |
# | time/                   |               |
# |    fps                  | 1393          |
# |    iterations           | 84            |
# |    time_elapsed         | 123           |
# |    total_timesteps      | 172032        |
# | train/                  |               |
# |    approx_kl            | 1.4173565e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.47e+11      |
# |    n_updates            | 830           |
# |    policy_gradient_loss | -1.82e-07     |
# |    value_loss           | 1.99e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.33e+07      |
# | time/                   |               |
# |    fps                  | 1388          |
# |    iterations           | 85            |
# |    time_elapsed         | 125           |
# |    total_timesteps      | 174080        |
# | train/                  |               |
# |    approx_kl            | 1.5133992e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.59e+11      |
# |    n_updates            | 840           |
# |    policy_gradient_loss | -2.43e-07     |
# |    value_loss           | 2.87e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.35e+07      |
# | time/                   |               |
# |    fps                  | 1393          |
# |    iterations           | 86            |
# |    time_elapsed         | 126           |
# |    total_timesteps      | 176128        |
# | train/                  |               |
# |    approx_kl            | 1.5628757e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.68e+11      |
# |    n_updates            | 850           |
# |    policy_gradient_loss | -9e-07        |
# |    value_loss           | 1.88e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.35e+07      |
# | time/                   |               |
# |    fps                  | 1397          |
# |    iterations           | 87            |
# |    time_elapsed         | 127           |
# |    total_timesteps      | 178176        |
# | train/                  |               |
# |    approx_kl            | 1.6903505e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.92e+11      |
# |    n_updates            | 860           |
# |    policy_gradient_loss | 2.15e-06      |
# |    value_loss           | 9.82e+11      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.35e+07      |
# | time/                   |               |
# |    fps                  | 1394          |
# |    iterations           | 88            |
# |    time_elapsed         | 129           |
# |    total_timesteps      | 180224        |
# | train/                  |               |
# |    approx_kl            | 1.4522811e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.29e+12      |
# |    n_updates            | 870           |
# |    policy_gradient_loss | 1.52e-06      |
# |    value_loss           | 2.75e+12      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.71e+03     |
# |    ep_rew_mean          | 2.44e+07     |
# | time/                   |              |
# |    fps                  | 1389         |
# |    iterations           | 89           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 1.580338e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.45e+11     |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -1.06e-06    |
# |    value_loss           | 1.49e+12     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.44e+07      |
# | time/                   |               |
# |    fps                  | 1394          |
# |    iterations           | 90            |
# |    time_elapsed         | 132           |
# |    total_timesteps      | 184320        |
# | train/                  |               |
# |    approx_kl            | 1.4988473e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.19e+12      |
# |    n_updates            | 890           |
# |    policy_gradient_loss | -1.06e-07     |
# |    value_loss           | 4.69e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.47e+07      |
# | time/                   |               |
# |    fps                  | 1389          |
# |    iterations           | 91            |
# |    time_elapsed         | 134           |
# |    total_timesteps      | 186368        |
# | train/                  |               |
# |    approx_kl            | 1.4872057e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.57e+11      |
# |    n_updates            | 900           |
# |    policy_gradient_loss | -7.22e-07     |
# |    value_loss           | 1.06e+12      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.71e+03      |
# |    ep_rew_mean          | 2.47e+07      |
# | time/                   |               |
# |    fps                  | 1386          |
# |    iterations           | 92            |
# |    time_elapsed         | 135           |
# |    total_timesteps      | 188416        |
# | train/                  |               |
# |    approx_kl            | 9.4546704e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.3e+12       |
# |    n_updates            | 910           |
# |    policy_gradient_loss | 4.48e-06      |
# |    value_loss           | 2.82e+12      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.71e+03     |
# |    ep_rew_mean          | 2.43e+07     |
# | time/                   |              |
# |    fps                  | 1390         |
# |    iterations           | 93           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 5.167385e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.12e+11     |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -3.06e-05    |
# |    value_loss           | 1.13e+12     |
# ------------------------------------------
# Done.

# %%
from static_thresh_base import ZScoreBaseline
from runner import run_strategy, plot_strategy

class SB3Agent:
    def __init__(self, model):
        self.model = model

    def predict(self, obs):
        flat = np.array([
            float(obs["position"]),
            abs(float(obs["spread_z_score"][0])),
            abs(float(obs["entry_z_score"][0])),
            abs(float(obs["spread"][0])),
            abs(float(obs["entry_spread"][0])),
        ], dtype=np.float32)
        action, _ = self.model.predict(flat, deterministic=True)
        return int(action)

env_kwargs = dict(fixed_beta=beta, spread_intercept=intercept, fixed_std=fixed_std)

# PPO on real Q4 (unseen)
q4_data = data.slice(q4)
results_ppo_q4 = run_strategy(Market(q4_data, **env_kwargs), SB3Agent(model))
print("--- PPO v2 (real Q4 test) ---")
plot_strategy(results_ppo_q4)

# Z-score baseline on real Q4
results_base_q4 = run_strategy(Market(q4_data, **env_kwargs), ZScoreBaseline(entry_threshold=2.0, exit_threshold=0.5))
print("--- Z-score baseline (real Q4 test) ---")
plot_strategy(results_base_q4)
# Out:
# --- PPO v2 (real Q4 test) ---
# /home/tudor/TUDelft/Y3/RP/rl_for_pairs_trading/project/runner_books/../runner.py:97: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[2].legend()
# /home/tudor/TUDelft/Y3/RP/rl_for_pairs_trading/project/runner_books/../runner.py:108: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[3].legend()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# --- Z-score baseline (real Q4 test) ---
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# PPO v2 and baseline on full real MCD/YUM dataset
results_ppo_full  = run_strategy(Market(data, **env_kwargs), SB3Agent(model))
print("--- PPO v2 (full real dataset) ---")
plot_strategy(results_ppo_full)

results_base_full = run_strategy(Market(data, **env_kwargs), ZScoreBaseline(entry_threshold=2.0, exit_threshold=0.5))
print("--- Z-score baseline (full real dataset) ---")
plot_strategy(results_base_full)
# Out:
# --- PPO v2 (full real dataset) ---
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# --- Z-score baseline (full real dataset) ---
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# PPO v2 on a single synthetic series (series 0)
synth_pair = object.__new__(PairData)
synth_pair.s = pairs[0]  # (2, T)
synth_pair.labels = ["s0 (synth)", "s1 (synth)"]
synth_pair.timestamps = np.arange(pairs.shape[2])

results_ppo_synth = run_strategy(Market(synth_pair, **env_kwargs), SB3Agent(model))
print("--- PPO v2 on synthetic series 0 ---")
plot_strategy(results_ppo_synth)

results_base_synth = run_strategy(Market(synth_pair, **env_kwargs), ZScoreBaseline(entry_threshold=2.0, exit_threshold=0.5))
print("--- Z-score baseline on synthetic series 0 ---")
plot_strategy(results_base_synth)
# Out:
# --- PPO v2 on synthetic series 0 ---
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# --- Z-score baseline on synthetic series 0 ---
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
